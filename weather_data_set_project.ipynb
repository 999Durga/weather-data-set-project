# %%
import numpy as np
import pandas as pd

# %%
#to_csv()
#pd.read_csv(" ")

# %%
weather=pd.read_csv("weather.csv")
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#isna()-to detect the missing values in the data ,it returns True for NA values and returns False for non-NA values.
weather.isna()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
#isna().sum()-returns the number of null values in the data
weather.isna().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
#isna().any()-to give null values for True and otherwise False
weather.isna().any()
# Out:
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RISK_MM          False
# RainTomorrow     False
# dtype: bool

# %%
weather.isnull()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
weather.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
weather.isnull().any()
# Out:
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RISK_MM          False
# RainTomorrow     False
# dtype: bool

# %%
#shape-to know how many rows and columns in the data
weather.shape
# Out:
# (366, 22)

# %%
#ndim-number of dimensions
weather.ndim
# Out:
# 2

# %%
#columns-to give columns names in the data
weather.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
weather.size
# Out:
# 8052

# %%
#head()-returns first n rows of a data
weather.head(5)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#tail()-returns last n rows of a data
weather.tail(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#info()-to give information about the and to know the data type also
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
#describe()-to give statistical  analyzation of the data
weather.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#drona()-to drop all null values in the data
#weather.dropna(inplace=True)

# %%
#weather.shape

# %%
#weather.isna().sum()

# %%
#weather.isna().any()

# %%
#fillna()#mean,mode-to replace the null values with a specified value
#ffill()
#bfill()

# %%
weather["Rainfall"].mean()
# Out:
# 1.428415300546448

# %%
weather.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
weather.isnull().any()
# Out:
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RISK_MM          False
# RainTomorrow     False
# dtype: bool

# %%
weather["Sunshine"].isnull().sum()
# Out:
# 3

# %%
weather["Sunshine"].fillna(weather["Sunshine"].mean(),inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\4075437760.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["Sunshine"].fillna(weather["Sunshine"].mean(),inplace=True)

# %%
weather["Sunshine"].isnull().sum()
# Out:
# 0

# %%
weather["WindGustDir"].isnull().sum()
# Out:
# 3

# %%
weather["WindGustDir"].fillna(weather["WindGustDir"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\699407938.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["WindGustDir"].fillna(weather["WindGustDir"].mode()[0],inplace=True)

# %%
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather["WindGustDir"].isnull().sum()
# Out:
# 0

# %%
weather["WindGustSpeed"].isnull().sum()
# Out:
# 2

# %%
weather["WindGustSpeed"].fillna(weather["WindGustSpeed"].mean(),inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\2341925400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["WindGustSpeed"].fillna(weather["WindGustSpeed"].mean(),inplace=True)

# %%
weather["WindGustSpeed"].isnull().sum()
# Out:
# 0

# %%
weather["WindDir9am"].isnull().sum()
# Out:
# 31

# %%
weather["WindDir9am"].fillna(weather["WindDir9am"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\4148296454.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["WindDir9am"].fillna(weather["WindDir9am"].mode()[0],inplace=True)

# %%
weather["WindDir9am"].isnull().sum()
# Out:
# 0

# %%
weather["WindDir3pm"].isnull().sum()
# Out:
# 1

# %%
weather["WindDir3pm"].fillna(weather["WindDir3pm"].mode()[0],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\452570601.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["WindDir3pm"].fillna(weather["WindDir3pm"].mode()[0],inplace=True)

# %%
weather["WindDir3pm"].isnull().sum()
# Out:
# 0

# %%
weather["WindSpeed9am"].isnull().sum()
# Out:
# 7

# %%
weather["WindSpeed9am"].fillna(weather["WindSpeed9am"].mean(),inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13724\704589503.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather["WindSpeed9am"].fillna(weather["WindSpeed9am"].mean(),inplace=True)

# %%
weather["WindSpeed9am"].isnull().sum()
# Out:
# 0

# %%
weather.isna().any()
# Out:
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine         False
# WindGustDir      False
# WindGustSpeed    False
# WindDir9am       False
# WindDir3pm       False
# WindSpeed9am     False
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RISK_MM          False
# RainTomorrow     False
# dtype: bool

# %%
weather.isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
weather.min()
# Out:
# MinTemp           -5.3
# MaxTemp            7.6
# Rainfall           0.0
# Evaporation        0.2
# Sunshine           0.0
# WindGustDir          E
# WindGustSpeed     13.0
# WindDir9am           E
# WindDir3pm           E
# WindSpeed9am       0.0
# WindSpeed3pm         0
# Humidity9am         36
# Humidity3pm         13
# Pressure9am      996.5
# Pressure3pm      996.8
# Cloud9am             0
# Cloud3pm             0
# Temp9am            0.1
# Temp3pm            5.1
# RainToday           No
# RISK_MM            0.0
# RainTomorrow        No
# dtype: object

# %%
weather.max()
# Out:
# MinTemp            20.9
# MaxTemp            35.8
# Rainfall           39.8
# Evaporation        13.8
# Sunshine           13.6
# WindGustDir         WSW
# WindGustSpeed      98.0
# WindDir9am          WSW
# WindDir3pm          WSW
# WindSpeed9am       41.0
# WindSpeed3pm         52
# Humidity9am          99
# Humidity3pm          96
# Pressure9am      1035.7
# Pressure3pm      1033.2
# Cloud9am              8
# Cloud3pm              8
# Temp9am            24.7
# Temp3pm            34.5
# RainToday           Yes
# RISK_MM            39.8
# RainTomorrow        Yes
# dtype: object

# %%
weather.shape
# Out:
# (366, 22)

# %%
weather.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
weather.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  366.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.467180
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    6.000000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     366.000000    366.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.023978      7.875308      8.856997    13.137058    16.850947
# ...

# %%
weather.size
# Out:
# 8052

# %%
weather.ndim
# Out:
# 2

# %%
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.tail()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
weather.loc[1:15,["WindGustSpeed","WindDir9am"]]
# Out:
#     WindGustSpeed WindDir9am
# 1            39.0          E
# 2            85.0          N
# 3            54.0        WNW
# 4            50.0        SSE
# 5            44.0         SE
# 6            43.0         SE
# 7            41.0         SE
# 8            48.0          E
# 9            31.0          S
# 10           30.0         SE

# %%
weather.iloc[1:15,0:10]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1      14.0     26.9       3.6          4.4       9.7         ENE
# 2      13.7     23.4       3.6          5.8       3.3          NW
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 4       7.6     16.1       2.8          5.6      10.6         SSE
# 5       6.2     16.9       0.0          5.8       8.2          SE
# 6       6.1     18.2       0.2          4.2       8.4          SE
# 7       8.3     17.0       0.0          5.6       4.6           E
# 8       8.8     19.5       0.0          4.0       4.1           S
# 9       8.4     22.8      16.2          5.4       7.7           E
# 10      9.1     25.2       0.0          4.2      11.9           N
# 11      8.5     27.3       0.2          7.2      12.5           E
# 12     10.1     27.9       0.0          7.2      13.0         WNW
# 13     12.1     30.9       0.0          6.2      12.4          NW
# ...

# %%
weather[["Temp9am","Temp3pm"]].median()
# Out:
# Temp9am    12.55
# Temp3pm    18.55
# dtype: float64

# %%
weather[["Temp9am","Temp3pm"]].mean()
# Out:
# Temp9am    12.358470
# Temp3pm    19.230874
# dtype: float64

# %%
weather[["Sunshine","WindGustSpeed","WindSpeed9am"]].value_counts().sort_values(ascending=False)
# Out:
# Sunshine  WindGustSpeed  WindSpeed9am
# 0.0       26.0           6.0             2
# 10.8      28.0           7.0             2
# 1.9       28.0           6.0             2
# 8.9       22.0           0.0             2
# 9.0       28.0           4.0             2
#                                         ..
# 13.2      44.0           4.0             1
# 13.3      57.0           6.0             1
# 13.5      52.0           6.0             1
# 13.6      30.0           6.0             1
#           31.0           7.0             1
# Name: count, Length: 361, dtype: int64

# %%
weather.pivot_table(index="RainToday",columns=["Evaporation","Sunshine"],values="MinTemp",aggfunc="sum").fillna(0).astype("int").unstack()
# Out:
# Evaporation  Sunshine  RainToday
# 0.2          0.5       No            0
#                        Yes          10
#              2.6       No            0
#                        Yes          10
# 0.6          0.0       No            9
#                                     ..
# 12.4         6.0       Yes           0
# 12.6         2.2       No           15
#                        Yes           0
# 13.8         6.9       No           20
#                        Yes           0
# Length: 698, dtype: int32
